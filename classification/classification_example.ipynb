# %%
import pandas as pd
import numpy as np

dt = pd.read_excel('/content/maliciousornot.xlsx')
dt.head()
# Out:
#    Type  URL_LENGTH  NUMBER_SPECIAL_CHARACTERS  ...    SOURCE_P    SOURCE_R    SOURCE_S
# 0     1   23.303047                  13.445560  ...    0.343781    0.595983    0.154015
# 1     1   26.645007                  23.018073  ...  240.932000  356.216667    0.115311
# 2     1   25.505113                  27.525833  ...  314.766000    0.468004    0.113445
# 3     1   14.792707                  26.398893  ...    0.333548    0.859842  224.092667
# 4     1   26.282313                  18.575080  ...    0.210492    0.306217    0.099456
#
# [5 rows x 31 columns]

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 548 entries, 0 to 547
# Data columns (total 31 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Type                       548 non-null    int64
#  1   URL_LENGTH                 548 non-null    float64
#  2   NUMBER_SPECIAL_CHARACTERS  548 non-null    float64
#  3   TCP_CONVERSATION_EXCHANGE  548 non-null    float64
#  4   DIST_REMOTE_TCP_PORT       548 non-null    float64
#  5   REMOTE_IPS                 548 non-null    float64
#  6   APP_BYTES                  548 non-null    float64
#  7   SOURCE_APP_PACKETS         548 non-null    float64
#  8   REMOTE_APP_PACKETS         548 non-null    float64
#  9   SOURCE_APP_BYTES           548 non-null    float64
#  10  REMOTE_APP_BYTES           548 non-null    float64
#  11  APP_PACKETS                548 non-null    float64
#  12  DNS_QUERY_TIMES            548 non-null    float64
# ...

# %%
dt.describe()
# Out:
#              Type    URL_LENGTH  NUMBER_SPECIAL_CHARACTERS  \
# count  548.000000    548.000000                 548.000000
# mean     0.383212    949.973475                  25.015747
# std      0.486613   3202.802599                   5.605685
# min      0.000000     10.051787                  12.577687
# 25%      0.000000     15.838688                  20.987638
# 50%      0.000000     18.069900                  24.423510
# 75%      1.000000     23.264187                  28.270650
# max      1.000000  12828.981333                  50.880693
#
#        TCP_CONVERSATION_EXCHANGE  DIST_REMOTE_TCP_PORT  REMOTE_IPS  \
# count                 548.000000            548.000000  548.000000
# mean                  119.725438            857.123249    5.785481
# std                    31.842845            461.579998   27.796268
# min                    56.722647            185.880333    0.068173
# 25%                    97.470595            544.622900    0.112309
# ...

# %%
dt.corr()["Type"].sort_values(ascending=False)
# Out:
# Type                         1.000000
# SOURCE_K                     0.784173
# TCP_CONVERSATION_EXCHANGE    0.744570
# SOURCE_M                     0.734002
# DIST_REMOTE_TCP_PORT         0.710294
# SOURCE_A                     0.536539
# SOURCE_J                     0.453197
# NUMBER_SPECIAL_CHARACTERS    0.412095
# APP_PACKETS                  0.240818
# SOURCE_P                     0.205141
# SOURCE_S                     0.141134
# REMOTE_APP_PACKETS           0.139874
# SOURCE_APP_PACKETS           0.129433
# REMOTE_IPS                   0.126232
# APP_BYTES                    0.096659
# SOURCE_N                     0.088076
# SOURCE_R                     0.069140
# SOURCE_O                     0.063622
# SOURCE_H                     0.055045
# SOURCE_D                     0.029479
# SOURCE_L                     0.022932
# SOURCE_E                     0.001985
# SOURCE_F                    -0.007551
# DNS_QUERY_TIMES             -0.011055
# SOURCE_G                    -0.017433
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.countplot(x=dt["Type"], data=dt)
# Out:
# <Axes: xlabel='Type', ylabel='count'>

# %%
dt.corr()["Type"].sort_values().plot(kind="bar")
# Out:
# <Axes: >

# %%
y=dt["Type"].values
y[:5]
# Out:
# array([1, 1, 1, 1, 1])

# %%
X = dt.drop(axis=1, labels="Type").values
X[:3]
# Out:
# array([[2.33030467e+01, 1.34455600e+01, 1.59066933e+02, 1.29662867e+03,
#         1.53367467e-01, 3.59584533e-01, 3.88729533e-01, 1.90543533e-01,
#         3.13341133e-01, 1.01955687e-01, 1.41839000e+03, 1.17266527e+00,
#         1.11256180e+04, 1.98704133e+02, 8.28883800e-03, 6.35231467e-02,
#         6.95982600e-02, 2.05569400e-02, 3.88988600e-02, 8.02199933e-03,
#         3.28755600e+01, 2.24481267e+01, 2.39118533e+02, 2.61527800e+03,
#         2.10103067e-01, 8.62173867e-01, 9.22147800e-01, 3.43781467e-01,
#         5.95982867e-01, 1.54015133e-01],
#        [2.66450067e+01, 2.30180733e+01, 1.72149800e+02, 1.71761200e+03,
#         1.09766547e-01, 1.01865013e-01, 1.12564467e-01, 9.08935400e-02,
#         2.34714400e-01, 7.34065400e-02, 7.04013667e-01, 9.50645133e-01,
#         4.40154267e+03, 9.59582933e+01, 6.76811667e-03, 1.69429600e-02,
#         2.40932000e-02, 1.73574667e-02, 1.79921800e-02, 4.57511733e-03,
# ...

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=15)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaler.fit(x_train)
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

x_train.shape
# Out:
# (383, 30)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(units=30, activation="relu"))
model.add(Dense(12, activation="relu"))
model.add(Dense(12, activation="relu"))
model.add(Dense(1, activation="sigmoid"))

model.compile(optimizer="adam" , loss="binary_crossentropy")

model.fit(x_train, y_train, epochs=700, validation_data=(x_test, y_test), verbose=1)
# Out:
# Epoch 1/700
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 67ms/step - loss: 0.6907 - val_loss: 0.6863
# Epoch 2/700
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.6798 - val_loss: 0.6803
# Epoch 3/700
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.6643 - val_loss: 0.6736
# Epoch 4/700
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.6556 - val_loss: 0.6609
# Epoch 5/700
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.6287 - val_loss: 0.6496
# Epoch 6/700
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.6087 - val_loss: 0.6362
# Epoch 7/700
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5917 - val_loss: 0.6166
# Epoch 8/700
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5668 - val_loss: 0.5921
# Epoch 9/700
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5224 - val_loss: 0.5602
# Epoch 10/700
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4929 - val_loss: 0.4998
# Epoch 11/700
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4244 - val_loss: 0.4562
# ...

# %%
model_kayip= pd.DataFrame(model.history.history)
model_kayip.plot()
# Out:
# <Axes: >

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping

model = Sequential()
model.add(Dense(units=30, activation="relu"))
model.add(Dense(12, activation="relu"))
model.add(Dense(12, activation="relu"))
model.add(Dense(1, activation="sigmoid"))

model.compile(optimizer="adam" , loss="binary_crossentropy")

earlyp_stopping = EarlyStopping(monitor="val_loss", mode="min", verbose=1, patience=25)

model.fit(x_train, y_train, epochs=700, validation_data=(x_test, y_test), verbose=1, callbacks=[earlyp_stopping], batch_size=383)
# Out:
# Epoch 1/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.6912 - val_loss: 0.6939
# Epoch 2/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - loss: 0.6883 - val_loss: 0.6922
# Epoch 3/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - loss: 0.6855 - val_loss: 0.6905
# Epoch 4/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - loss: 0.6828 - val_loss: 0.6889
# Epoch 5/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 0.6803 - val_loss: 0.6873
# Epoch 6/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - loss: 0.6777 - val_loss: 0.6858
# Epoch 7/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.6753 - val_loss: 0.6844
# Epoch 8/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 0.6727 - val_loss: 0.6829
# Epoch 9/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.6702 - val_loss: 0.6815
# Epoch 10/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 0.6677 - val_loss: 0.6802
# Epoch 11/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.6653 - val_loss: 0.6788
# Epoch 12/700
# ...

# %%
model_kaybi= pd.DataFrame(model.history.history)
model_kaybi.plot()
# Out:
# <Axes: >

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.callbacks import EarlyStopping

model = Sequential()
model.add(Dense(units=30, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(12, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(12, activation="relu"))
model.add(Dropout(0.5))

model.add(Dense(1, activation="sigmoid"))

model.compile(optimizer="adam" , loss="binary_crossentropy")

earlyp_stopping = EarlyStopping(monitor="val_loss", mode="min", verbose=1, patience=25)

# %%
model.fit(x_train, y_train, epochs=700, validation_data=(x_test, y_test), verbose=1, callbacks=[earlyp_stopping], batch_size=383)
# Out:
# Epoch 1/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 692.3627 - val_loss: 325.8890
# Epoch 2/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 582.8491 - val_loss: 308.3424
# Epoch 3/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 609.9463 - val_loss: 291.0428
# Epoch 4/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 564.9559 - val_loss: 274.2019
# Epoch 5/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 498.0398 - val_loss: 257.9924
# Epoch 6/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 537.4486 - val_loss: 242.4628
# Epoch 7/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 641.3152 - val_loss: 227.5279
# Epoch 8/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 377.0828 - val_loss: 213.3197
# Epoch 9/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 468.7831 - val_loss: 199.9629
# Epoch 10/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 436.0512 - val_loss: 186.9165
# Epoch 11/700
# ...

# %%
model_kaybi= pd.DataFrame(model.history.history)
model_kaybi.plot()
# Out:
# <Axes: >
